# %%
import matplotlib.pyplot as plt
from math import cos

# %%
x = [i for i in range(-1, 12)]
y = [cos(i) for i in x]

# %%
plt.plot(x, y)
plt.xlim([-2, 12])
plt.ylim([-2, 2])
plt.annotate("first", (-1, cos(-1)))
plt.show()
