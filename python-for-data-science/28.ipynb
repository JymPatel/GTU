# %% [markdown]
# **Practical 28**
#
# Write a python program to plot image and display it’s information. Generate another
# image from previous image by cropping it.

# %%
import matplotlib.image as img
import matplotlib.pyplot as plt
# %matplotlib inline
image = img.imread("smiley.jpg")
print(image.shape)
print(image.size)
plt.imshow(image)
plt.show()
# Out:
# (485, 728, 3)
# 1059240

# %%
image = image[100:350,150:550]
plt.imshow(image)
plt.show()
