# %% [markdown]
# **Practical 24**
# Write Python program to plot time series with trends of sales.

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('sales.csv', index_col='Order Date')
plt.plot(df.index, df['Units Sold'])
plt.xlabel('Date')
plt.ylabel('Sales')
plt.show()
